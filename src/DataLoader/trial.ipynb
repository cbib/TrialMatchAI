# %%
import pandas as pd

df = pd.read_csv("../../data/NCT_trialOncoX_basic.tsv", sep="\t", dtype=str)

# %%
df["nct_id"].unique()
# Out:
# array(['NCT01000025', 'NCT01000129', 'NCT01000246', ..., 'NCT06458413',
#        'NCT06458439', 'NCT06458517'], dtype=object)
